# %%
#importing libraries
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings=

# %%
df=pd.read_csv("employee_dataset_for_eda.csv")
df
# Out:
#      Employee_ID  Age  Gender   Department       Location  \
# 0           1001   50  Female    Marketing         Austin
# 1           1002   36  Female        Sales       New York
# 2           1003   29    Male    Marketing  San Francisco
# 3           1004   42  Female           HR  San Francisco
# 4           1005   40  Female    Marketing         Austin
# ..           ...  ...     ...          ...            ...
# 195         1196   40  Female           HR       New York
# 196         1197   41    Male      Finance  San Francisco
# 197         1198   53    Male           HR       New York
# 198         1199   28  Female           HR         Austin
# 199         1200   54    Male  Engineering         Austin
#
#      Years_of_Experience  Monthly_Salary  Performance_Score
# 0                      4          105046               79.6
# 1                      1           59287               71.7
# 2                      5           69711               87.2
# ...

# %%
#employee count per department
sns.countplot(data=df,x='Department',palette='Set2')
plt.title("employee count per department")
# Out:
# C:\Users\kirti\AppData\Local\Temp\ipykernel_13344\4064061901.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df,x='Department',palette='Set2')
# Text(0.5, 1.0, 'employee count per department')

# %% [markdown]
# finance department having greater than count of employee

# %%
#gender distribution
sns.countplot(data=df,x="Gender",palette="coolwarm")
plt.title("gender distribution")
# Out:
# C:\Users\kirti\AppData\Local\Temp\ipykernel_13344\4226524938.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df,x="Gender",palette="coolwarm")
# Text(0.5, 1.0, 'gender distribution')

# %%
#employee loccation distribution
sns.countplot(data=df,x="Location",palette="Spectral")
plt.title("Number of Employees by Location")
plt.xticks(rotation=45)
# Out:
# C:\Users\kirti\AppData\Local\Temp\ipykernel_13344\4155891134.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df,x="Location",palette="Spectral")
# ([0, 1, 2, 3, 4],
#  [Text(0, 0, 'Austin'),
#   Text(1, 0, 'New York'),
#   Text(2, 0, 'San Francisco'),
#   Text(3, 0, 'Seattle'),
#   Text(4, 0, 'Chicago')])

# %% [markdown]
# Employees work in seattle more than other

# %%
#Age distribution
sns.histplot(df['Age'],bins=10,kde=True)
plt.title("Age distribution")
# Out:
# Text(0.5, 1.0, 'Age distribution')

# %% [markdown]
# 45-50 is greater than followed by 25-30

# %%
#years of experience distribution
sns.histplot(df["Years_of_Experience"],bins=10,kde=True)
plt.title("Years_of_Experience")
# Out:
# Text(0.5, 1.0, 'Years_of_Experience')

# %% [markdown]
# year 2.5 - 5.0 is greater followed by 12.5

# %%
#monthly salary distribution
sns.boxplot(data=df,y="Monthly_Salary",color="darkpink")
plt.title("salary spread")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 2
#       1 #monthly salary distribution
# ----> 2 sns.boxplot(data=df,y="Monthly_Salary",color="darkpink")
#       3 plt.title("salary spread")
#
# File D:\ml\anaconda3\Lib\site-packages\seaborn\categorical.py:1627, in boxplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, fill, dodge, width, gap, whis, linecolor, linewidth, fliersize, hue_norm, native_scale, log_scale, formatter, legend, ax, **kwargs)
#    1625 saturation = saturation if fill else 1
#    1626 p.map_hue(palette=palette, order=hue_order, norm=hue_norm, saturation=saturation)
# -> 1627 color = _default_color(
#    1628     ax.fill_between, hue, color,
#    1629     {k: v for k, v in kwargs.items() if k in ["c", "color", "fc", "facecolor"]},
#    1630     saturation=saturation,
#    1631 )
# ...
